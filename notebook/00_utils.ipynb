# %% [markdown]
# # Utils Module
#
# ## Overview
#
# This module contains reusable utility functions used across the NASA Meteorite Analytics Platform.
#
# The objective of this package is to centralize common logic in order to:
#
# - Improve code maintainability
# - Reduce code duplication
# - Simplify notebook development
# - Facilitate future scalability of the platform
#
# ---
#
# ## Author
#
# **Loïc Di Pietrantonio**
# Data & Business Analyst | Data Engineering Enthusiast
#
# ---
#
# ## Creation Date
#
# **2026-06-04**
#
# ---
#
# ## Last Update
#
# **2026-06-04**
#
# ---
#
# ## Project
#
# NASA Meteorite Analytics Platform
#
# End-to-end Data Engineering project built on:
#
# - Python
# - Azure Blob Storage
# - Databricks
# - Delta Lake
# - Unity Catalog
# - Power BI
#
# ---
#
# ## Folder Structure
#
# ```text
# src/
# └── utils/
#     ├── file_utils.py
#     ├── date_utils.py
#     └── notebook_utils.py

# %%
# import
import os
import sys
from pathlib import Path
from pyspark.sql.types import DoubleType, StringType, IntegerType, DateType
from pyspark.sql.functions import current_timestamp, lit, explode, col, when, count, to_timestamp

# %%
# Created params 
workspace_link = '/Workspace/Users/loic.dipietrantonio@wizzarco.com/NASA-Meteorite-Analytics-Platform'
