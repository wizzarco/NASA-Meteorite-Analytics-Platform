# %%
# %run ../00_utils

# %% [markdown]
# # ***Bronze Load***

# %% [markdown]
# ### Check if the file are available

# %%
# Check path
display(dbutils.fs.ls(workspace_link + "/data/bronze/delta")) # paths & name table require

# %%
# Take the last full and compare if the file is up to date
files = [
    f for f in dbutils.fs.ls(workspace_link + "/data/bronze/delta")
    if f.name.endswith(".json")
]

latest_file = max(
    files,
    key=lambda x: x.modificationTime
)

print(latest_file.path)

# %%
df = (spark.read.option("multiline", "true").json(latest_file.path))

# %%
# Check the schema for transform the data
# df.printSchema()

# %%
# df.limit(10).display()

# %%
# Add the current timestamp when he load + source fil to check if the data is up to date
bronze_df = (
    df
    .withColumn("ingestion_timestamp", current_timestamp())
    .withColumn("source_file", lit(latest_file.name))
)

# %% [markdown]
# %md
# ## _Create table_

# %%
bronze_df.write.mode("overwrite").format("delta").saveAsTable("nasa_meteor.bronze_delta")

# %%
# bronze_full = spark.table("nasa_meteor.bronze_delta")
# bronze_df.display()
